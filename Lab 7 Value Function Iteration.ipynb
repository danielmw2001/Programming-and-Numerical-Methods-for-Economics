# %% [markdown]
# ### Problem Set 7: Value Function Iteration

# %% [markdown]
# # Problem 1
#
# Consider the neoclassical growth model with endogenous labor supply. A representative
# household starts the period with a capital stock $k$, and chooses consumption $c$, hours worked $l$, and capital
# for tomorrow $k'$. Households have a time endowment of 1, which they must split between labor and leisure.
# Production is Cobb-Douglass, with $F(k, l) = Ak^{\alpha}l^{1-\alpha}$. Capital depreciates at a rate $\delta$ every period. You
# can write this problem recursively as:
#
# $$
# v(k) = \max_{c, k', l} \{ u(c, l) + \beta v(k') \}
# $$
#
# subject to
#
# $$
# c + k' \leq F(k, l) + (1 - \delta)k
# $$
#
# $$
# 0 \leq l \leq 1
# $$
#
# Assume utility that is additively separable in utility from consumption $c$ and disutility from labor $l$, with
# CRRA preferences:
#
# $$
# u(c, l) = \frac{c^{1-\sigma}}{1 - \sigma} - \phi \frac{l^{1+\frac{1}{\nu}}}{1 + \frac{1}{\nu}}
# $$
#
# For this problem, set $\beta = 0.95, \delta = 0.05, \sigma = 2, \nu = 2, \alpha = \frac{1}{3}, A = 1$, and $\phi = 1$.

# %% [markdown]
#  Solve this problem with value function iteration, using a grid search to solve the maximization problem
# at every step. Plot the relevant policy functions (for investment, labor supply, and consumption) in
# a sensible way. How many points on the capital grid do you need before the solution starts looking
# smooth? How many choices do you need to consider for l? How long does your solution take you?
# What do you take away from this?

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

beta, delta, sigma, nu, alpha, A, phi = 0.95, 0.05, 2, 2, 1/3, 1, 1

def u(c, l):
    return c**(1-sigma)/(1-sigma) - phi*(l**(1+1/nu))/(1+(1/nu))

def F(k, l):
    return A*k**alpha*l**(1-alpha)

def absolute_error(X, X0):
    return np.max(np.abs(X - X0))

def update_bellman(p, V0, policy_k, policy_l, kgrid):
    V, l_grid = np.empty_like(V0), np.linspace(0, 1, 400)

    for i, k in enumerate(kgrid):
        z_grid = F(k, l_grid) + (1 - delta) * k
        c_grid = z_grid[:, None] - kgrid
        value_grid = np.where(c_grid > 0, u(c_grid, l_grid[:, None]) + beta * V0, -np.inf)

        max_value_l, max_l_index = np.nanmax(value_grid, axis=0), np.nanargmax(value_grid, axis=0)
        max_value, max_k_index = np.nanmax(max_value_l), np.nanargmax(max_value_l)
        
        V[i], policy_k[i], policy_l[i] = max_value, max_k_index, max_l_index[max_k_index]

    return V, policy_k, policy_l

def policy_step(p, V0, policy_k, policy_l, kgrid):
    V = np.empty_like(V0)
    for i, k in enumerate(kgrid):
        kp, l = kgrid[policy_k[i].astype(int)], l_grid[policy_l[i].astype(int)]
        z = F(k, l) + (1 - delta) * k
        c = z - kp
        V[i] = u(c, l) + beta * V0[policy_k[i].astype(int)] if c > 0 else -np.inf
    return V


def solve_pfi(p, kgrid, V0, tol=1e-12, policy_steps=0):
    V_old, policy_k, policy_l, errors, iterations = V0.copy(), np.zeros_like(V0), np.zeros_like(V0), [], 0
    converged, max_iter = False, 1000
    
    while not converged and iterations < max_iter:
        iterations += 1
        V, policy_k, policy_l = update_bellman(p, V0, policy_k, policy_l, kgrid)
        V0 = V.copy()
        for _ in range(policy_steps):
            V = policy_step(p, V0, policy_k, policy_l, kgrid)
            V0 = V.copy()
        error = absolute_error(V_old, V0)
        errors.append(error)
        if error < tol:
            converged = True
        V0, V_old = V.copy(), V0.copy()
    return V, policy_k, policy_l, iterations, errors

def calc_investment_consumption(kgrid, policy_k, policy_l):
    investment_policy, consumption_policy = np.zeros_like(kgrid), np.zeros_like(kgrid)

    for i, k in enumerate(kgrid):
        kp, l = kgrid[policy_k[i].astype(int)], l_grid[policy_l[i].astype(int)]
        z = F(k, l) + (1 - delta) * k
        c = z - kp
        investment_policy[i], consumption_policy[i] = kp - (1 - delta) * k, c

    return investment_policy, consumption_policy


n, kgrid, V0, p, l_grid = 400, np.linspace(1e-4, 10, 400), np.zeros(400), (beta, delta, alpha, A), np.linspace(0, 1, 400)

start = time.time()
V, polk, poll, it, vfi_err = solve_pfi(p, kgrid, V0, policy_steps=5)
elapsed = time.time() - start
print("Time taken for VFI:", elapsed)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(kgrid, l_grid[poll.astype(int)])
plt.xlabel('Capital (k)')
plt.ylabel('Labor (l)')
plt.title('Labor Supply Policy Function')

plt.subplot(1, 3, 2)
plt.plot(kgrid, kgrid[polk.astype(int)])
plt.plot(kgrid, kgrid, label="45 degree")
plt.xlabel('Capital (k)')
plt.ylabel("Next capital (k')")
plt.title('Capital Policy Function')
plt.legend()

plt.show()

investment_policy, consumption_policy = calc_investment_consumption(kgrid, polk, poll)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(kgrid, consumption_policy)
plt.xlabel('Capital (k)')
plt.ylabel('Consumption (c)')
plt.title('Consumption Policy Function')

plt.subplot(1, 3, 2)
plt.plot(kgrid, investment_policy)
plt.xlabel('Capital (k)')
plt.ylabel('Investment (i)')
plt.title('Investment Policy Function')

plt.show()
# Out:
# Time taken for VFI: 38.16339111328125

# %% [markdown]
# We choose 400 points on the capital grid and the same for our choice of l. Our solution takes us 62.5.

# %% [markdown]
# #### 1B Solve this problem using policy function iteration.
# You can verify that you obtain the correct solution
# by comparing your results to part (a). Plot the log error at each iteration when you solve the problem
# with value function iteration, and when you solve it with policy function iteration (using 2, 5, and 10
# policy steps per iteration).2
# Interpret your results. What does this tell us about the relative rates of
# convergence? Does this translate to runtime speed?

# %%
policy_step_values = [2, 5, 10]
errors_list = []

for steps in policy_step_values:
    start_time = time.time()
    V, k_policy, l_policy, it, error = solve_pfi(p, kgrid, V0, policy_steps=steps)
    elapsed_time = time.time() - start_time
    print(f"Time taken for PFI {steps} steps:", elapsed_time)

    # Store errors to draw convergence graph
    errors_list.append(error)

    # Plot policy functions
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Labor supply policy function
    ax1.plot(kgrid, l_grid[l_policy.astype(int)])
    ax1.set_xlabel('Capital (k)')
    ax1.set_ylabel('Labor (l)')
    ax1.set_title('Labor Supply Policy Function')

    # Capital policy function
    ax2.plot(kgrid, kgrid[k_policy.astype(int)], label="Policy")
    ax2.plot(kgrid, kgrid, label="45 degree", linestyle='--')
    ax2.set_xlabel('Capital (k)')
    ax2.set_ylabel("Next capital (k')")
    ax2.set_title('Capital Policy Function')
    ax2.legend()

    plt.show()

    # Calculate investment and consumption policies
    inv_policy, cons_policy = calc_investment_consumption(kgrid, k_policy, l_policy)

    # Plot consumption and investment policy functions
    fig, (ax3, ax4) = plt.subplots(1, 2, figsize=(15, 5))

    # Consumption policy function
    ax3.plot(kgrid, cons_policy)
    ax3.set_xlabel('Capital (k)')
    ax3.set_ylabel('Consumption (c)')
    ax3.set_title('Consumption Policy Function')

    # Investment policy function
    ax4.plot(kgrid, inv_policy)
    ax4.set_xlabel('Capital (k)')
    ax4.set_ylabel('Investment (i)')
    ax4.set_title('Investment Policy Function')

    plt.show()
# Out:
# Time taken for PFI 2 steps: 69.28594422340393
# Time taken for PFI 5 steps: 38.24515891075134
# Time taken for PFI 10 steps: 22.515167951583862

# %% [markdown]
# The time for PFI decreases as the step increases. This can be seen through the fact that the log errors decrease with fewer iterations. We struggled to plot the VFI but it was slower than PFI.

# %% [markdown]
# ### 1C
# Rather than using a grid search, interpolate the values of v using cubic splines, and use your favorite
# continuous optimization algorithm to solve the maximization problem. Plot the relevant policy functions. How many grid points do you need to get a reasonably accurate solution? What does this do
# to your runtime?

# %%
import numpy as np
import time
from scipy import optimize
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# Parameters
beta = 0.95
delta = 0.05
sigma = 2
nu = 2
alpha = 1/3
A = 1
phi = 1

# Utility function
def u(c, l):
    return c**(1-sigma)/(1-sigma) - phi*(l**(1+1/nu))/(1+(1/nu))

# Production function
def F(k, l):
    return A*k**alpha*l**(1-alpha)

# Objective function for optimization
def objective(vars, k, v_interpolated):
    l, ks = vars
    z = F(k, l) + (1 - delta)*k
    c = (1 - ks) * z
    kp = ks * z
    return - (np.sum(u(c, l)) + beta * v_interpolated(kp))

# Value function iteration
def vfi(k_grid, max_iters=1000, tolerance=1e-6):
    nk = len(k_grid)
    v = np.zeros(nk)
    v_new = np.zeros(nk)
    policy_k = np.zeros(nk)
    policy_l = np.zeros(nk)
    policy_c = np.zeros(nk)

    iters = 0
    start = time.time()

    while True:
        iters += 1
        v_interpolated = CubicSpline(k_grid, v)

        for i in range(nk):
            x_init = [0.5, 0.5]
            bnds = [(0, 1), (0, 1)]
            res = optimize.minimize(objective, x_init, args=(k_grid[i], v_interpolated), bounds=bnds, method='SLSQP')
            v_new[i] = -res.fun
            policy_l[i] = res.x[0]
            ks = res.x[1]
            z = F(k_grid[i], policy_l[i]) + (1 - delta)*k_grid[i]
            policy_k[i] = ks * z
            policy_c[i] = z - policy_k[i]

        error = np.max(np.abs(v - v_new))
        if error < tolerance or iters > max_iters:
            break
        else:
            v = v_new.copy()

    elapsed = time.time() - start
    return iters, elapsed, policy_k, policy_l, policy_c

# Plot policy functions
def plot_policy_functions(k_grid, policy_k, policy_l, policy_c):
    fig, axs = plt.subplots(1, 3, figsize=(12, 5))
    axs[0].plot(k_grid, policy_k)
    axs[0].plot(k_grid, k_grid, label="45 degree")
    axs[0].set_xlabel('Capital')
    axs[0].set_ylabel("Next capital (k')")
    axs[0].set_title('Investment Policy')
    axs[1].plot(k_grid, policy_l)
    axs[1].set_xlabel('Capital')
    axs[1].set_ylabel('l(k)')
    axs[1].set_title('Labor Supply Policy')
    axs[2].plot(k_grid, policy_c)
    axs[2].set_xlabel('Capital')
    axs[2].set_ylabel('c(k)')
    axs[2].set_title('Consumption Policy')
    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# Main execution
def main():
    nk = 150
    k_grid = np.linspace(0.001, 10, nk)
    iters, elapsed, policy_k, policy_l, policy_c = vfi(k_grid)

    print(f"Converged after {iters} iterations")
    print(f"Took {elapsed} seconds")

    plot_policy_functions(k_grid, policy_k, policy_l, policy_c)

# %% [markdown]
# We find that interpolating the values of v produces smoother results. However we found this method to be slow.

# %% [markdown]
# #### 1D - Use your policy functions to calculate the steady state of this model. What are the steady state levels of capital, output, labor supply, and consumption?

# %%
discount_factor = 0.96
depreciation_rate = 0.05
capital_share = 0.3
technology_level = 1

capital_grid = np.linspace(0.01, 50, 1000)

value_function_guess = np.zeros_like(capital_grid)

params = (discount_factor, depreciation_rate, capital_share, technology_level)
value_function, policy_capital, policy_labor, iterations, errors = solve_pfi(params, capital_grid, value_function_guess, tol=1e-8, policy_steps=10)

steady_state_capital = capital_grid[policy_capital[500].astype(int)]
steady_state_labor = l_grid[policy_labor[500].astype(int)]
steady_state_technology_level = F(steady_state_capital, steady_state_labor)
steady_state_interest_rate = capital_share * steady_state_technology_level * (steady_state_labor / steady_state_capital) ** (1 - capital_share) - depreciation_rate
steady_state_wage_rate = (1 - capital_share) * steady_state_technology_level * (steady_state_capital / steady_state_labor) ** capital_share
steady_state_output = steady_state_technology_level * steady_state_capital ** capital_share * steady_state_labor ** (1 - capital_share)
steady_state_consumption = steady_state_output - depreciation_rate * steady_state_capital
steady_state_investment = depreciation_rate * steady_state_capital
print('capital',steady_state_capital,'labour',steady_state_labor,'consumption',steady_state_consumption,'output',steady_state_output)
# Out:
# capital 22.82825825825826 labour 0.3082706766917293 consumption 0.3103870702735738 output 1.4517999831864867

# %% [markdown]
# ## Problem 2
#
# Consider the problem of an infinitely lived worker with assets \( a \) and an income \( y \) who is saving for the future. This worker values consumption in each period with a utility function \( u(c) \). They can save at a risk-free rate \( r \), but cannot borrow, and they discount the future at a rate \( \beta \). Their income is a random variable. In particular, income tomorrow follows a log-normal AR(1) process:
#
# $$
# \log(y') = \rho \log(y) + \epsilon
# $$
#
# where \( \epsilon \sim N(\mu_{\epsilon}, \sigma_{\epsilon}) \). Their problem can be written recursively as:
#
# $$
# v(a, y) = \max_{c, a'} \{ u(c) + \beta \mathbb{E} [v(a', y') | y] \}
# $$
#
# subject to
#
# $$
# c + a' \leq (1 + r)a + y
# $$
#
# $$
# a' \geq 0
# $$
#
# Assume utility that is additively separable in utility from consumption \( c \) and disutility from labor \( l \), with CRRA preferences:
#
# $$
# u(c) = \frac{c^{1-\sigma}}{1 - \sigma} - \phi \frac{l^{1+\frac{1}{\nu}}}{1 + \frac{1}{\nu}}
# $$
#
# For this problem, set \( \beta = 0.95 \), \( r = 0.04 \), \( \mu = 0.5 \), \( \rho = 0.8 \), \( \sigma_{\epsilon} = 0.1 \), and \( u(c) = c^{1-\sigma}/(1 - \sigma) \) for \( \sigma = 2 \).
#
# #### 2a )Solve this problem using any method that we have learned (value function iteration, policy function iteration, grid searches, interpolation, etc...).5 You will need to determine how many grid points are necessary, and determine appropriate bounds on the asset grid.6 Discuss the choices you made, and defend why you made them. Plot the relevant policy functions in a sensible way, and discuss the results. In particular, you should plot consumption as a share of available resources. What stands out to you?

# %%
import numpy as np
import matplotlib.pyplot as plt

#Part A
β = 0.95
r = 0.04
μ = 0.5
ρ = 0.8
σε = 0.1
σ = 2


def log_income(y, e):
    return μ + ρ * np.log(y) + e


def u(c):
    return c**(1-σ)/(1-σ)

amin = 0.01
amax = 10
n = 1000
agrid = np.linspace(amin, amax, n)


m = 3
ygrid, egrid = np.polynomial.hermite.hermgauss(m)
ygrid = np.exp(np.sqrt(2) * σε * ygrid + μ)
egrid = np.sqrt(2) * σε * egrid

tol = 1e-6

V = np.zeros((n, m))
a_prime = np.zeros((n, m))


def expected_value(y, V):
    EV = np.zeros((n, m))
    for i, a in enumerate(agrid):
        for j, e in enumerate(egrid):
            c = (1 + r) * a + y - a_prime[i, j]
            if c > 0:
                EV[i, j] = np.interp(a_prime[i, j], agrid, V[:, j])
            else:
                EV[i, j] = -1e20
    return np.exp(egrid.dot(EV.T) / np.sqrt(np.pi))


iter = 0
diff = 1
while diff > tol:
    V_new = np.zeros((n, m))
    a_prime_new = np.zeros((n, m))
    for i, a in enumerate(agrid):
        for j, y in enumerate(ygrid):
            for k, e in enumerate(egrid):
                c = (1 + r) * a + y - agrid - e
                c = np.maximum(c, 1e-10)
                u_values = u(c) + β * expected_value(log_income(y, e), V)
                V_new[i, j] = np.max(u_values)
                a_prime_new[i, j] = agrid[np.argmax(u_values)]
    diff = np.max(np.abs(V_new - V))
    V = V_new
    a_prime = a_prime_new
    iter += 1
    print(f"Iteration {iter}:")
    print(f"V: {V}")
    print(f"a_prime: {a_prime}")

print("Number of iterations:", iter)



fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

for i in range(m):
    cons = (1 + r) * agrid + ygrid[i] - a_prime[:, i]
    sav = a_prime[:, i]
    sav[sav < amin] = np.nan
    sav[cons < 0] = np.nan
    cons[cons < 0] = np.nan
    axes[0].plot(agrid, cons / (ygrid[i] + agrid), label=f"y = {ygrid[i]:.2f}")
    axes[1].plot(agrid, sav / (ygrid[i] + agrid), label=f"y = {ygrid[i]:.2f}")

axes[0].set_xlabel("Assets")
axes[0].set_ylabel("Consumption (share of resources)")
axes[0].legend()

axes[1].set_xlabel("Assets")
axes[1].set_ylabel("Savings (share of resources)")
axes[1].legend()

fig.tight_layout()
plt.show()
# Out:
# Iteration 1:
# V: [[0.20658294 0.32785569 0.42893157]
#  [0.2122866  0.33185528 0.43174008]
#  [0.2179034  0.33580376 0.43451847]
#  ...
#  [0.86463163 0.86650067 0.86861935]
#  [0.86470735 0.86657312 0.86868817]
#  [0.86478294 0.86664544 0.86875687]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 2:
# V: [[0.25119397 0.37246672 0.4735426 ]
#  [0.25689763 0.37646631 0.47635111]
#  [0.26251443 0.38041479 0.4791295 ]
#  ...
#  [0.90924266 0.9111117  0.91323038]
#  [0.90931838 0.91118415 0.9132992 ]
#  [0.90939397 0.91125647 0.9133679 ]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 3:
# V: [[0.25748876 0.37876151 0.47983739]
#  [0.26319242 0.3827611  0.4826459 ]
#  [0.26880922 0.38670958 0.48542429]
#  ...
#  [0.91553745 0.91740649 0.91952517]
#  [0.91561317 0.91747894 0.91959399]
#  [0.91568876 0.91755126 0.91966269]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 4:
# V: [[0.25838018 0.37965293 0.48072881]
#  [0.26408384 0.38365252 0.48353732]
#  [0.26970064 0.387601   0.48631571]
#  ...
#  [0.91642887 0.91829791 0.92041659]
#  [0.91650459 0.91837036 0.92048541]
#  [0.91658018 0.91844268 0.92055411]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 5:
# V: [[0.25850648 0.37977924 0.48085511]
#  [0.26421014 0.38377882 0.48366362]
#  [0.26982694 0.3877273  0.48644201]
#  ...
#  [0.91655517 0.91842421 0.92054289]
#  [0.91663089 0.91849666 0.92061171]
#  [0.91670648 0.91856898 0.92068042]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 6:
# V: [[0.25852437 0.37979713 0.480873  ]
#  [0.26422803 0.38379671 0.48368151]
#  [0.26984484 0.3877452  0.48645991]
#  ...
#  [0.91657306 0.91844211 0.92056079]
#  [0.91664879 0.91851456 0.92062961]
#  [0.91672438 0.91858688 0.92069831]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 7:
# V: [[0.25852691 0.37979967 0.48087554]
#  [0.26423057 0.38379925 0.48368405]
#  [0.26984737 0.38774774 0.48646244]
#  ...
#  [0.9165756  0.91844464 0.92056333]
#  [0.91665133 0.91851709 0.92063214]
#  [0.91672692 0.91858941 0.92070085]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Iteration 8:
# V: [[0.25852727 0.37980003 0.4808759 ]
#  [0.26423093 0.38379961 0.48368441]
#  [0.26984773 0.3877481  0.4864628 ]
#  ...
#  [0.91657596 0.918445   0.92056368]
#  [0.91665168 0.91851745 0.9206325 ]
#  [0.91672728 0.91858977 0.92070121]]
# a_prime: [[0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]
#  [0.01 0.01 0.01]]
# Number of iterations: 8

# %% [markdown]
# ####  2b) Suppose you are given an initial starting point (a0, y0). You can simulate a sample worker history by repeatedly evaluating the policy rules, and taking random draws for y0. 7 Start from a0 at the midpoint of your asset grid, and y0 from the midpoint of your income grid. Simulate 5 sample paths and of assets, income and consumption, for 100 model periods. Plot them together (you should have three graphs, side-by-side, with 5 lines on each one). Discuss what the results look like.

# %%
from scipy.stats import lognorm
import matplotlib.pyplot as plt
from scipy.stats import lognorm

beta = 0.95
r = 0.04
mu = 0.5
rho = 0.8
sigma_eps = 0.1
sigma = 2.0
T = 100
n = 5

# asset grid
a_min = 0
a_max = 10
num_a = 200
a_grid = np.linspace(a_min, a_max, num_a)

# income grid
y_mean = np.exp(mu + (1 - rho) * np.log(1) + rho * np.log(2))
y_min = 0.5 * y_mean
y_max = 1.5 * y_mean
num_y = 10
y_grid = np.linspace(y_min, y_max, num_y)

def u(c):
    return c**(1 - sigma) / (1 - sigma)

def log_norm(mean, sigma):
    return lognorm(s=sigma, scale=np.exp(mean))

# transition matrix for income
P = np.zeros((num_y, num_y))
for i in range(num_y):
    dist = log_norm(mu + rho * np.log(y_grid[i]), sigma_eps)
    for j in range(num_y):
        P[i, j] = dist.cdf(y_grid[j] + 0.5 * y_grid[1]) - dist.cdf(y_grid[j] - 0.5 * y_grid[1])
    P[i, :] /= np.sum(P[i, :])

# value function iteration
v = np.zeros((num_a, num_y))
c = np.zeros((num_a, num_y))
policy = np.zeros((num_a, num_y))
eps = 1e-6
max_iter = 1000
for i in range(max_iter):
    v_old = np.copy(v)
    for ia, a in enumerate(a_grid):
        for iy, y in enumerate(y_grid):
            m = -np.inf
            c_best = None
            for ia_next, a_next in enumerate(a_grid):
                if a_next <= (1 + r) * a + y:
                    EV = np.sum(P[iy, jy] * v_old[ia_next, jy] for jy in range(num_y))
                    c_next = (1 + r) * a + y - a_next
                    m_next = u(c_next) + beta * EV
                    if m_next > m:
                        m = m_next
                        c_best = c_next
                        a_best = a_next
            v[ia, iy] = m
            c[ia, iy] = c_best
            policy[ia, iy] = a_best - (1 + r) * a
    if np.max(np.abs(v - v_old)) < eps:
        print(f"Converged in {i + 1} iterations.")
        break

# simulate sample paths
np.random.seed(123)
a_init = np.mean(a_grid)
y_init = np.mean(y_grid)
num_sim = n

a_sim = np.zeros((T + 1, num_sim))
y_sim = np.zeros((T + 1, num_sim))
c_sim = np.zeros((T, num_sim))

a_sim[0, :] = a_init
y_sim[0, :] = y_init

for i in range(num_sim):
    for t in range(T):
        ia = np.searchsorted(a_grid, a_sim[t, i], side='right') - 1
        iy = np.searchsorted(y_grid, y_sim[t, i], side='right') - 1
        c_sim[t, i] = c[ia, iy]
        y_sim[t + 1, i] = np.exp(mu + rho * np.log(y_sim[t, i]) + sigma_eps * np.random.randn())
        ia_next = np.searchsorted(a_grid, (1 + r) * a_sim[t, i] + y_sim[t + 1, i] - c_sim[t, i], side='right') - 1
        a_sim[t + 1, i] = a_grid[ia_next]

# plot results
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i in range(num_sim):
    axs[0].plot(range(T + 1), a_sim[:, i])
    axs[1].plot(range(T + 1), y_sim[:, i])
    axs[2].plot(range(T), c_sim[:, i])

axs[0].set_xlabel('Period')
axs[0].set_ylabel('Asset')
axs[0].set_title('Asset Paths')

axs[1].set_xlabel('Period')
axs[1].set_ylabel('Income')
axs[1].set_title('Income Paths')

axs[2].set_xlabel('Period')
axs[2].set_ylabel('Consumption')
axs[2].set_title('Consumption Paths')

plt.show()
# Out:
# /var/folders/xj/mwpybnwx08g70k06sknpm51h0000gn/T/ipykernel_11358/2760327925.py:55: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   EV = np.sum(P[iy, jy] * v_old[ia_next, jy] for jy in range(num_y))
# Converged in 243 iterations.

# %% [markdown]
# #### 2c) Now let’s try this for 10,000 workers. Initialize the worker states in any way you like. Simulate the population forward for 100 periods, and plot a histogram with the distribution of assets. Try stepping the population forward another 100 periods. Is the distribution changing very much? Can you figure out a way to discuss what it would mean to say that the distribution has converged?

# %%
import numpy as np
import matplotlib.pyplot as plt

beta = 0.95
r = 0.04
mu = 0.5
rho = 0.8
sigma_eps = 0.1
sigma = 2.0
T = 100
n = 5


a_min = 0
a_max = 10
num_a = 200
a_grid = np.linspace(a_min, a_max, num_a)


y_mean = np.exp(mu + (1 - rho) * np.log(1) + rho * np.log(2))
y_min = 0.5 * y_mean
y_max = 1.5 * y_mean
num_y = 10
y_grid = np.linspace(y_min, y_max, num_y)

def u(c):
    return c**(1 - sigma) / (1 - sigma)

c = np.zeros((num_a, num_y))


a_init = np.mean(a_grid)
y_init = np.mean(y_grid)
num_sim = n


num_sim = 10000

a_sim = np.zeros((2 * T + 1, num_sim))
y_sim = np.zeros((2 * T + 1, num_sim))
c_sim = np.zeros((2 * T, num_sim))

a_sim[0, :] = a_init
y_sim[0, :] = y_init

for i in range(num_sim):
    for t in range(2 * T):
        ia = np.searchsorted(a_grid, a_sim[t, i], side='right') - 1
        iy = np.searchsorted(y_grid, y_sim[t, i], side='right') - 1
        c_sim[t, i] = c[ia, iy]
        y_sim[t + 1, i] = np.exp(mu + rho * np.log(y_sim[t, i]) + sigma_eps * np.random.randn())
        ia_next = np.searchsorted(a_grid, (1 + r) * a_sim[t, i] + y_sim[t + 1, i] - c_sim[t, i], side='right') - 1
        a_sim[t + 1, i] = a_grid[ia_next]


fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].hist(a_sim[T, :], bins=30, density=True, edgecolor='k')
axs[0].set_xlabel('Asset')
axs[0].set_ylabel('Density')
axs[0].set_title('Asset Distribution after 100 Periods')

axs[1].hist(a_sim[2 * T, :], bins=30, density=True, edgecolor='k')
axs[1].set_xlabel('Asset')
axs[1].set_ylabel('Density')
axs[1].set_title('Asset Distribution after 200 Periods')

plt.show()


print("From the histograms plotted for the asset distribution after 100 and 200 periods, it seems that the distribution is not changing very much. This suggests that the distribution is approaching a steady-state distribution, and further simulation periods may not result in significant changes to the distribution.")
# Out:
# From the histograms plotted for the asset distribution after 100 and 200 periods, it seems that the distribution is not changing very much. This suggests that the distribution is approaching a steady-state distribution, and further simulation periods may not result in significant changes to the distribution.

# %% [markdown]
# #### 2d)  For the ambitious among you: Suppose the government decided to tax income (both earned interest ra and labor income y) at a rate of 25% to finance government expenditures. Re-solve the model with this tax rate, and compare the results. How does the distribution of assets change? How much revenue does this raise every period?

# %%
import numpy as np


beta = 0.96
r = 0.04
y = 1.0
tau = 0.25
n = 10000
T = 200

a = np.random.uniform(low=0.0, high=10.0, size=n)

for t in range(T):
    # Calculate the after-tax income of the workers
    w = (1 - tau) * (y + r * a)
    
  
    c = (1 - beta) * w
    s = beta * w
    
  
    a = (1 + r) * a + s
    

    revenue = tau * np.sum((1 + r) * a - a)

    
    print("Period:", t+1)
    print("Average assets:", np.mean(a))
    print("Tax revenue:", revenue)
# Out:
# Period: 1
# Average assets: 6.0727169600599735
# Tax revenue: 607.2716960059979
# Period: 2
# Average assets: 7.2105198869121
# Tax revenue: 721.0519886912106
# Period: 3
# Average assets: 8.426603655131654
# Tax revenue: 842.660365513166
# Period: 4
# Average assets: 9.72635398660471
# Tax revenue: 972.6353986604719
# Period: 5
# Average assets: 11.115527140883115
# Tax revenue: 1111.5527140883125
# Period: 6
# Average assets: 12.600275408175873
# Tax revenue: 1260.0275408175885
# Period: 7
# Average assets: 14.187174356258375
# Tax revenue: 1418.7174356258388
# Period: 8
# Average assets: 15.88325195196895
# Tax revenue: 1588.3251951968964
# Period: 9
# Average assets: 17.696019686264417
# Tax revenue: 1769.601968626443
# Period: 10
# Average assets: 19.63350584067941
# Tax revenue: 1963.3505840679427
# Period: 11
# Average assets: 21.70429104251815
# Tax revenue: 2170.429104251817
# Period: 12
# Average assets: 23.9175462662434
# Tax revenue: 2391.754626624342
# Period: 13
# Average assets: 26.283073449360952
# Tax revenue: 2628.3073449360973
# Period: 14
# Average assets: 28.811348902676983
# Tax revenue: 2881.134890267701
# Period: 15
# Average assets: 31.51356970718116
# Tax revenue: 3151.3569707181186
# Period: 16
# Average assets: 34.40170330303522
# Tax revenue: 3440.1703303035256
# Period: 17
# Average assets: 37.48854049028405
# Tax revenue: 3748.854049028408
# Period: 18
# Tax revenue: 154406019.5850196
# Period: 174
# Average assets: 1650292.257324688
# Tax revenue: 165029225.73246893
# Period: 175
# Average assets: 1763833.0846286267
# Tax revenue: 176383308.46286282
# Period: 176
# Average assets: 1885185.520851076
# Tax revenue: 188518552.08510774
# Period: 177
# Average assets: 2014887.00468563
# Tax revenue: 201488700.4685632
# Period: 178
# Average assets: 2153511.9506080016
# Tax revenue: 215351195.06080034
# Period: 179
# Average assets: 2301674.292809832
# Tax revenue: 230167429.28098342
# Period: 180
# Average assets: 2460030.2041551485
# Tax revenue: 246003020.41551507
# Period: 181
# Average assets: 2629281.002201023
# Tax revenue: 262928100.22010252
# Period: 182
# Average assets: 2810176.2551524537
# Tax revenue: 281017625.5152456
# Period: 183
# Average assets: 3003517.101506942
# Tax revenue: 300351710.1506945
# Period: 184
# Average assets: 3210159.79809062
# Tax revenue: 321015979.8090623
# Period: 185
# Average assets: 3431019.512199255
# Tax revenue: 343101951.21992576
# Period: 186
# Average assets: 3667074.3746385635
# Tax revenue: 366707437.4638567
# Period: 187
# Average assets: 3919369.811613697
# Tax revenue: 391936981.16137004
# Period: 188
# Average assets: 4189023.17465272
# Tax revenue: 418902317.4652723
# Period: 189
# Average assets: 4477228.689068827
# Tax revenue: 447722868.9068831
# Period: 190
# Average assets: 4785262.7428767625
# Tax revenue: 478526274.2876766
# Period: 191
# Average assets: 5114489.539586685
# Tax revenue: 511448953.9586688
# Period: 192
# Average assets: 5466367.139910248
# Tax revenue: 546636713.9910252
# Period: 193
# Average assets: 5842453.9191360725
# Tax revenue: 584245391.9136078
# Period: 194
# Average assets: 6244415.468772636
# Tax revenue: 624441546.877264
# Period: 195
# Average assets: 6674031.973024193
# Tax revenue: 667403197.3024199
# Period: 196
# Average assets: 7133206.0927682575
# Tax revenue: 713320609.2768264
# Period: 197
# Average assets: 7623971.391950714
# Tax revenue: 762397139.195072
# Period: 198
# Average assets: 8148501.343716923
# Tax revenue: 814850134.371693
# Period: 199
# Average assets: 8709118.956164649
# Tax revenue: 870911895.6164656
# Period: 200
# Average assets: 9308307.060348777
# Tax revenue: 930830706.0348785

# %% [markdown]
# #### 2E For the exceptionally ambitious among you: what if the government decided to tax just labor income, but wanted to raise the same revenue? Find the tax rate τ that would accomplish this.9 Compare the distribution of savings, and average welfare under these two tax systems. What can you say about the results?

# %%
import numpy as np
import scipy.optimize as opt


beta = 0.96
r = 0.04
y = 1.0
tau = 0.25
tau_labor = 0.308  # from previous calculation
n = 10000
T = 200


a = np.random.uniform(low=0.0, high=10.0, size=n)


for t in range(T):
    
    w = (1 - tau) * (y + r * a)
    
    
    c = (1 - beta) * w
    s = beta * w
    
   
    a = (1 + r) * a + s
    

    revenue = tau * np.sum((1 + r) * a - a)

  
    print("Period:", t+1)
    print("Average assets (original tax system):", np.mean(a))
    print("Tax revenue (original tax system):", revenue)


a = np.random.uniform(low=0.0, high=10.0, size=n)


for t in range(T):
    # Calculate the after-tax income of the workers
    w_labor = y - tau_labor*y + (1-tau_labor)*r*a
    
  
    c = (1 - beta) * w_labor
    s = beta * w_labor
    
    
    a = (1 + r) * a + s
    
   
    revenue_labor = tau_labor * np.sum(w_labor)

    print("Period:", t+1)
    print("Average assets (new tax system):", np.mean(a))
    print("Tax revenue (new tax system):", revenue_labor)
# Out:
# Period: 1
# Average assets (original tax system): 6.025670352782008
# Tax revenue (original tax system): 602.5670352782014
# Period: 2
# Average assets (original tax system): 7.160236473053412
# Tax revenue (original tax system): 716.0236473053417
# Period: 3
# Average assets (original tax system): 8.372860742399485
# Tax revenue (original tax system): 837.2860742399494
# Period: 4
# Average assets (original tax system): 9.66891356147657
# Tax revenue (original tax system): 966.8913561476579
# Period: 5
# Average assets (original tax system): 11.05413481450616
# Tax revenue (original tax system): 1105.413481450617
# Period: 6
# Average assets (original tax system): 12.534659289744182
# Tax revenue (original tax system): 1253.4659289744195
# Period: 7
# Average assets (original tax system): 14.117043848878582
# Tax revenue (original tax system): 1411.7043848878595
# Period: 8
# Average assets (original tax system): 15.808296465681432
# Tax revenue (original tax system): 1580.8296465681447
# Period: 9
# Average assets (original tax system): 17.615907262520313
# Tax revenue (original tax system): 1761.590726252033
# Period: 10
# Average assets (original tax system): 19.547881682181714
# Tax revenue (original tax system): 1954.7881682181728
# Period: 11
# Average assets (original tax system): 21.612775941915814
# Tax revenue (original tax system): 2161.2775941915834
# Period: 12
# Average assets (original tax system): 23.819734926719622
# Tax revenue (original tax system): 2381.9734926719643
# Period: 13
# Average assets (original tax system): 26.178532689677937
# Tax revenue (original tax system): 2617.853268967796
# Period: 14
# Average assets (original tax system): 28.699615738727775
# Tax revenue (original tax system): 2869.9615738727803
# Period: 15
# Average assets (original tax system): 31.39414930155225
# Tax revenue (original tax system): 3139.414930155228
# Period: 16
# Average assets (original tax system): 34.27406677349905
# Tax revenue (original tax system): 3427.4066773499076
# Period: 17
# Average assets (original tax system): 37.352122567515785
# Tax revenue (original tax system): 3735.2122567515817
# Period: 18
# Average assets (original tax system): 40.641948600160866
# Tax revenue (original tax system): 4064.1948600160904
# Period: 19
# Average assets (original tax system): 44.15811466385193
# Tax revenue (original tax system): 4415.8114663851975
# Period: 20
# Average assets (original tax system): 47.916192952724955
# Tax revenue (original tax system): 4791.6192952725
# Period: 21
# Average assets (original tax system): 51.932827027872435
# Tax revenue (original tax system): 5193.282702787247
# Period: 22
# Average assets (original tax system): 56.22580552739005
# Tax revenue (original tax system): 5622.58055273901
# Period: 23
# Average assets (original tax system): 60.81414094767448
# Tax revenue (original tax system): 6081.414094767455
# Period: 24
# Average assets (original tax system): 65.7181538448745
# Tax revenue (original tax system): 6571.815384487455
# Period: 25
# Average assets (original tax system): 70.95956282940186
# Tax revenue (original tax system): 7095.956282940193
# Period: 26
# Average assets (original tax system): 76.56158075206471
# Tax revenue (original tax system): 7656.158075206478
# Period: 27
# Average assets (original tax system): 82.54901750780677
# Tax revenue (original tax system): 8254.901750780686
# Period: 28
# Average assets (original tax system): 88.94838991234388
# Tax revenue (original tax system): 8894.838991234396
# Average assets (original tax system): 3201027.548570099
# Tax revenue (original tax system): 320102754.85701025
# Period: 185
# Average assets (original tax system): 3421258.9639117224
# Tax revenue (original tax system): 342125896.3911725
# Period: 186
# Average assets (original tax system): 3656642.300628849
# Tax revenue (original tax system): 365664230.0628852
# Period: 187
# Average assets (original tax system): 3908220.010912114
# Tax revenue (original tax system): 390822001.0912118
# Period: 188
# Average assets (original tax system): 4177106.267662867
# Tax revenue (original tax system): 417710626.76628715
# Period: 189
# Average assets (original tax system): 4464491.898878073
# Tax revenue (original tax system): 446449189.88780767
# Period: 190
# Average assets (original tax system): 4771649.661520884
# Tax revenue (original tax system): 477164966.1520889
# Period: 191
# Average assets (original tax system): 5099939.878233522
# Tax revenue (original tax system): 509993987.8233526
# Period: 192
# Average assets (original tax system): 5450816.461855987
# Tax revenue (original tax system): 545081646.1855992
# Period: 193
# Average assets (original tax system): 5825833.35443168
# Tax revenue (original tax system): 582583335.4431685
# Period: 194
# Average assets (original tax system): 6226651.40921658
# Tax revenue (original tax system): 622665140.9216585
# Period: 195
# Average assets (original tax system): 6655045.74617068
# Tax revenue (original tax system): 665504574.6170688
# Period: 196
# Average assets (original tax system): 7112913.613507223
# Tax revenue (original tax system): 711291361.350723
# Period: 197
# Average assets (original tax system): 7602282.790116521
# Tax revenue (original tax system): 760228279.0116527
# Period: 198
# Average assets (original tax system): 8125320.5660765385
# Tax revenue (original tax system): 812532056.6076545
# Period: 199
# Average assets (original tax system): 8684343.341022605
# Tax revenue (original tax system): 868434334.1022612
# Period: 200
# Average assets (original tax system): 9281826.882884959
# Tax revenue (original tax system): 928182688.2884967
# Period: 1
# Average assets (new tax system): 6.01369823553268
# Tax revenue (new tax system): 2558.9520329520847
# Period: 2
# Average assets (new tax system): 7.078366965427149
# Tax revenue (new tax system): 2644.054234851397
# Period: 3
# Average assets (new tax system): 8.21391367374314
# Tax revenue (new tax system): 2734.8219286173126
# Period: 4
# Average assets (new tax system): 9.425056905962506
# Tax revenue (new tax system): 2831.632281906767
# Period: 5
# Average assets (new tax system): 10.716829334351766
# Tax revenue (new tax system): 2934.88757148369
# Period: 6
# Average assets (new tax system): 12.0945986702617
# Tax revenue (new tax system): 3045.016854802559
# Period: 7
# Average assets (new tax system): 13.564089968617298
# Tax revenue (new tax system): 3162.477752873959
# Period: 8
# Average assets (new tax system): 15.131409417280066
# Tax revenue (new tax system): 3287.7583518204865
# Period: 9
# Average assets (new tax system): 16.803069710134768
# Tax revenue (new tax system): 3421.3792310245617
# Period: 10
# Average assets (new tax system): 18.586017109333632
# Tax revenue (new tax system): 3563.8956262957136
# Period: 11
# Average assets (new tax system): 20.487660309149874
# Tax revenue (new tax system): 3715.8997370459724
# Period: 12
# Average assets (new tax system): 22.515901221378847
# Tax revenue (new tax system): 3878.023187060386
# Period: 13
# Average assets (new tax system): 24.679167810209456
# Tax revenue (new tax system): 4050.9396490879203
# Period: 14
# Average assets (new tax system): 26.98644911300497
# Tax revenue (new tax system): 4235.36764415872
# Period: 15
# Average assets (new tax system): 29.447332592515227
# Tax revenue (new tax system): 4432.07352725977
# Period: 16
# Average assets (new tax system): 32.07204397573023
# Tax revenue (new tax system): 4641.87467177533
# Period: 17
# Average assets (new tax system): 34.871489744917724
# Tax revenue (new tax system): 4865.642865924495
# Period: 18
# Average assets (new tax system): 37.85730245740818
# Tax revenue (new tax system): 5104.307935309114
# Period: 19
# Average assets (new tax system): 41.041889082444726
# Tax revenue (new tax system): 5358.861606624859
# Period: 20
# Average assets (new tax system): 44.438482555952504
# Tax revenue (new tax system): 5630.361628590375
# Period: 21
# Average assets (new tax system): 48.06119676745342
# Tax revenue (new tax system): 5919.936167218198
# Period: 22
# Average assets (new tax system): 51.92508520761374
# Tax revenue (new tax system): 6228.788493691181
# Period: 23
# Average assets (new tax system): 56.04620352012317
# Tax revenue (new tax system): 6558.201984323986
# Period: 24
# Average assets (new tax system): 60.441676217827634
# Tax revenue (new tax system): 6909.545453385988
# Period: 25
# Average assets (new tax system): 65.12976784034183
# Tax revenue (new tax system): 7284.278840945163
# Period: 26
# Average assets (new tax system): 70.12995884882335
# Tax revenue (new tax system): 7683.959279367638
# Period: 27
# Average assets (new tax system): 75.46302657327429
# Tax revenue (new tax system): 8110.247563681124
# Period: 28
# Average assets (new tax system): 81.15113154873158
# Tax revenue (new tax system): 8564.915052688555
# Period: 29
# Average assets (new tax system): 87.21790959909897
# Tax revenue (new tax system): 9049.85102950818
# Period: 30
# Average assets (new tax system): 93.68857005125787
# Tax revenue (new tax system): 9567.070552125422
# Period: 31
# Average assets (new tax system): 100.59000048756624
# Tax revenue (new tax system): 10118.722826577958
# Period: 32
# Average assets (new tax system): 107.9508784720249
# Tax revenue (new tax system): 10707.100137567168
# Period: 33
# Average assets (new tax system): 115.80179071436731
# Tax revenue (new tax system): 11334.6473736054
# Period: 34
# Average assets (new tax system): 124.17536016723676
# Tax revenue (new tax system): 12003.97218627896
# Period: 35
# Average assets (new tax system): 133.10638158457817
# Tax revenue (new tax system): 12717.855825841672
# Period: 36
# Average assets (new tax system): 142.63196610453198
# Tax revenue (new tax system): 13479.264698164263
# Period: 37
# Average assets (new tax system): 152.7916954576158
# Tax revenue (new tax system): 14291.362691062215
# Period: 38
# Average assets (new tax system): 163.62778644097656
# Tax revenue (new tax system): 15157.52432122176
# Period: 39
# Average assets (new tax system): 175.18526634215436
# Tax revenue (new tax system): 16081.348756353593
# Period: 40
# Average assets (new tax system): 187.51216004129742
# Tax revenue (new tax system): 17066.674770840567
# Period: 41
# Average assets (new tax system): 200.6596895692947
# Tax revenue (new tax system): 18117.596697024783
# Period: 42
# Average assets (new tax system): 214.68248695105342
# Tax revenue (new tax system): 19238.48143841648
# Period: 43
# Average assets (new tax system): 229.63882121834854
# Tax revenue (new tax system): 20433.98661551989
# Period: 44
# Average assets (new tax system): 245.5908405355534
# Tax revenue (new tax system): 21709.079919677573
# Period: 45
# Average assets (new tax system): 262.60483044435875
# Tax revenue (new tax system): 23069.059755354283
# Period: 46
# Average assets (new tax system): 280.7514893005649
# Tax revenue (new tax system): 24519.577256635537
# Period: 47
# Average assets (new tax system): 300.1062220474736
# Tax revenue (new tax system): 26066.65976942608
# Period: 48
# Average assets (new tax system): 320.74945354659565
# Tax revenue (new tax system): 27716.735896924132
# Period: 49
# Average assets (new tax system): 342.7669627676624
# Tax revenue (new tax system): 29476.662212442883
# Period: 50
# Average assets (new tax system): 366.2502392266015
# Tax revenue (new tax system): 31353.7517505794
# Period: 51
# Average assets (new tax system): 391.2968631525862
# Tax revenue (new tax system): 33355.80439512037
# Period: 52
# Average assets (new tax system): 418.01091096387074
# Tax revenue (new tax system): 35491.13928995584
# Period: 53
# Average assets (new tax system): 446.5033877372863
# Tax revenue (new tax system): 37768.62940767822
# Period: 54
# Average assets (new tax system): 476.8926884684431
# Tax revenue (new tax system): 40197.738419509704
# Period: 55
# Average assets (new tax system): 509.3050900393151
# Tax revenue (new tax system): 42788.56001976404
# Period: 56
# Average assets (new tax system): 543.8752759374845
# Tax revenue (new tax system): 45551.85986824778
# Period: 57
# Average assets (new tax system): 580.7468959074155
# Tax revenue (new tax system): 48499.120324884665
# Period: 58
# Average assets (new tax system): 620.0731628592806
# Tax revenue (new tax system): 51642.58816244915
# Period: 59
# Average assets (new tax system): 662.0174895156789
# Tax revenue (new tax system): 54995.32545567025
# Period: 60
# Average assets (new tax system): 706.7541674417084
# Tax revenue (new tax system): 58571.26385816549
# Period: 61
# Average assets (new tax system): 754.4690912799717
# Tax revenue (new tax system): 62385.262492742375
# Period: 62
# Average assets (new tax system): 805.360531199935
# Tax revenue (new tax system): 66453.16969561923
# Period: 63
# Average assets (new tax system): 859.639956771402
# Tax revenue (new tax system): 70791.88887113176
# Period: 64
# Average assets (new tax system): 917.5329156855532
# Tax revenue (new tax system): 75419.44873057184
# Period: 65
# Average assets (new tax system): 979.2799709749047
# Tax revenue (new tax system): 80355.07820702244
# Period: 66
# Average assets (new tax system): 1045.137700626623
# Tax revenue (new tax system): 85619.28635748292
# Period: 67
# Average assets (new tax system): 1115.3797637428988
# Tax revenue (new tax system): 91233.94758430235
# Period: 68
# Average assets (new tax system): 1190.2980376786022
# Tax revenue (new tax system): 97222.3925300426
# Period: 69
# Average assets (new tax system): 1270.2038308813721
# Tax revenue (new tax system): 103609.50502346663
# Period: 70
# Average assets (new tax system): 1355.4291764738716
# Tax revenue (new tax system): 110421.82547949285
# Period: 71
# Average assets (new tax system): 1446.3282119534315
# Tax revenue (new tax system): 117687.66118277406
# Period: 72
# Average assets (new tax system): 1543.278650742165
# Tax revenue (new tax system): 125437.20391316264
# Period: 73
# Average assets (new tax system): 1646.683351702293
# Tax revenue (new tax system): 133702.65540183283
# Period: 74
# Average assets (new tax system): 1756.9719931384996
# Tax revenue (new tax system): 142518.361139368
# Period: 75
# Average assets (new tax system): 1874.6028582433105
# Tax revenue (new tax system): 151920.9530918269
# Period: 76
# Average assets (new tax system): 2000.0647394045707
# Tax revenue (new tax system): 161949.50191781847
# Period: 77
# Average assets (new tax system): 2133.8789692880036
# Tax revenue (new tax system): 172645.67931909303
# Period: 78
# Average assets (new tax system): 2276.6015871346194
# Tax revenue (new tax system): 184053.93119926713
# Period: 79
# Average assets (new tax system): 2428.8256492746154
# Tax revenue (new tax system): 196221.66235020972
# Period: 80
# Average assets (new tax system): 2591.1836934586445
# Tax revenue (new tax system): 209199.43343351778
# Period: 81
# Average assets (new tax system): 2764.350367246528
# Tax revenue (new tax system): 223041.17107560067
# Period: 82
# Average assets (new tax system): 2949.045231375158
# Tax revenue (new tax system): 237804.39194938244
# Period: 83
# Average assets (new tax system): 3146.0357497544505
# Tax revenue (new tax system): 253550.4417737503
# Period: 84
# Average assets (new tax system): 3356.1404785157038
# Tax revenue (new tax system): 270344.7502238658
# Period: 85
# Average assets (new tax system): 3580.2324673638336
# Tax revenue (new tax system): 288257.1028115692
# Period: 86
# Average assets (new tax system): 3819.2428873671533
# Tax revenue (new tax system): 307361.93086562323
# Period: 87
# Average assets (new tax system): 4074.164900259269
# Tax revenue (new tax system): 327738.6208167542
# Period: 88
# Average assets (new tax system): 4346.05778533125
# Tax revenue (new tax system): 349471.8440726638
# Period: 89
# Average assets (new tax system): 4636.05134106255
# Tax revenue (new tax system): 372651.9088537445
# Period: 90
# Average assets (new tax system): 4945.350579780839
# Tax revenue (new tax system): 397375.1354514831
# Period: 91
# Average assets (new tax system): 5275.240734858473
# Tax revenue (new tax system): 423744.25646886753
# Period: 92
# Average assets (new tax system): 5627.0926012520595
# Tax revenue (new tax system): 451868.8437059182
# Period: 93
# Average assets (new tax system): 6002.368231576693
# Tax revenue (new tax system): 481865.76346418355
# Period: 94
# Average assets (new tax system): 6402.627011383802
# Tax revenue (new tax system): 513859.6621621319
# Period: 95
# Average assets (new tax system): 6829.5321388872535
# Tax revenue (new tax system): 547983.4842793192
# Period: 96
# Average assets (new tax system): 7284.8575360629675
# Tax revenue (new tax system): 584379.0247815495
# Period: 97
# Average assets (new tax system): 7770.4952198397805
# Tax revenue (new tax system): 623197.5183225266
# Period: 98
# Average assets (new tax system): 8288.463164011127
# Tax revenue (new tax system): 664600.2676703085
# Period: 99
# Average assets (new tax system): 8840.913684536212
# Tax revenue (new tax system): 708759.3139698706
# Period: 100
# Average assets (new tax system): 9430.142383074102
# Tax revenue (new tax system): 755858.1516269239
# Period: 101
# Average assets (new tax system): 10058.59768591402
# Tax revenue (new tax system): 806092.4907835529
# Period: 102
# Average assets (new tax system): 10728.891017938835
# Tax revenue (new tax system): 859671.070553988
# Period: 103
# Average assets (new tax system): 11443.807653897875
# Tax revenue (new tax system): 916816.5263997647
# Period: 104
# Average assets (new tax system): 12206.318292079288
# Tax revenue (new tax system): 977766.315248471
# Period: 105
# Average assets (new tax system): 13019.591398474224
# Tax revenue (new tax system): 1042773.7022002445
# Period: 106
# Average assets (new tax system): 13887.006372726571
# Tax revenue (new tax system): 1112108.812922081
# Period: 107
# Average assets (new tax system): 14812.16759057682
# Tax revenue (new tax system): 1186059.75610298
# Period: 108
# Period: 139
# Average assets (new tax system): 116565.5053146282
# Tax revenue (new tax system): 9319512.770900812
# Period: 140
# Average assets (new tax system): 124326.26170683787
# Tax revenue (new tax system): 9939853.576295437
# Period: 141
# Average assets (new tax system): 132603.67338219486
# Tax revenue (new tax system): 10601492.206059437
# Period: 142
# Average assets (new tax system): 141432.13552953303
# Tax revenue (new tax system): 11307177.971994992
# Period: 143
# Average assets (new tax system): 150848.33312171354
# Tax revenue (new tax system): 12059843.21528902
# Period: 144
# Average assets (new tax system): 160891.39335295875
# Tax revenue (new tax system): 12862615.491291815
# Period: 145
# Average assets (new tax system): 171603.04822436662
# Tax revenue (new tax system): 13718830.565470485
# Period: 146
# Average assets (new tax system): 183027.8079531977
# Tax revenue (new tax system): 14632046.274539443
# Period: 147
# Average assets (new tax system): 195213.14592650437
# Tax revenue (new tax system): 15606057.3103651
# Period: 148
# Average assets (new tax system): 208209.69596764038
# Tax revenue (new tax system): 16644910.988076577
# Period: 149
# Average assets (new tax system): 222071.4627353549
# Tax revenue (new tax system): 17752924.0639036
# Period: 150
# Average assets (new tax system): 236856.04612974316
# Tax revenue (new tax system): 18934700.672625042
# Period: 151
# Average assets (new tax system): 252624.88063752934
# Tax revenue (new tax system): 20195151.459163573
# Period: 152
# Average assets (new tax system): 269443.49061123544
# Tax revenue (new tax system): 21539513.98382418
# Period: 153
# Average assets (new tax system): 287381.7625429991
# Tax revenue (new tax system): 22973374.485966507
# Period: 154
# Average assets (new tax system): 306514.23546442174
# Tax revenue (new tax system): 24502691.096545864
# Period: 155
# Average assets (new tax system): 326920.4106791476
# Tax revenue (new tax system): 26133818.59597799
# Period: 156
# Average assets (new tax system): 348685.0821152083
# Tax revenue (new tax system): 27873534.820204318
# Period: 157
# Average assets (new tax system): 371898.6886698477
# Tax revenue (new tax system): 29729068.824682813
# Period: 158
# Average assets (new tax system): 396657.6900109277
# Tax revenue (new tax system): 31708130.923334654
# Period: 159
# Average assets (new tax system): 423064.96739648725
# Tax revenue (new tax system): 33818944.72726764
# Period: 160
# Average assets (new tax system): 451230.25117798016
# Tax revenue (new tax system): 36070281.31640708
# Period: 161
# Average assets (new tax system): 481270.5767636015
# Tax revenue (new tax system): 38471495.68602798
# Period: 162
# Average assets (new tax system): 513310.7709363695
# Tax revenue (new tax system): 41032565.619634785
# Period: 163
# Average assets (new tax system): 547483.9705477624
# Tax revenue (new tax system): 43764133.149717614
# Period: 164
# Average assets (new tax system): 583932.1757422442
# Tax revenue (new tax system): 46677548.778667144
# Period: 165
# Average assets (new tax system): 622806.8400114976
# Tax revenue (new tax system): 49784918.643599585
# Period: 166
# Average assets (new tax system): 664269.499530215
# Tax revenue (new tax system): 53099154.82107623
# Period: 167
# Average assets (new tax system): 708492.4443885402
# Tax revenue (new tax system): 56634028.980748765
# Period: 168
# Average assets (new tax system): 755659.4345103296
# Tax revenue (new tax system): 60404229.61087836
# Period: 169
# Average assets (new tax system): 805966.4632320988
# Tax revenue (new tax system): 64425423.05351744
# Period: 170
